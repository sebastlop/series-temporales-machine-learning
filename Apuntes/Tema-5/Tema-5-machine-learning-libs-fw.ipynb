# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()
a = 2
b = -1
x = rng.uniform(0,1,100)
y = a *x + b + rng.normal(0,0.1,size=len(x))
plt.scatter(x,y)

# %%
def loss(y, y_hat):
    return np.mean((y_hat-y)**2)

def dloss(a, b, x, y_hat):
    da = -2*np.mean((y_hat-a*x-b)*x)
    db = -2*np.mean((y_hat-a*x-b))
    return da, db

def train(x, y_hat, epochs = 10, a = 1, b=1, lr = 0.2):
    history = [[a,b,loss(a*x+b, y_hat)]]
    for i in range(epochs):
        grad = dloss(a,b,x,y_hat)
        a = a - lr * grad[0]
        b = b - lr * grad[1]
        history.append([a,b,loss(a*x+b,y_hat)])
    return a,b, history

# %%
a,b,hist = train(x, y_hat = y, epochs= 1000)

# %%
pp = [h[2] for h in hist]

# %%
plt.semilogy(pp)
